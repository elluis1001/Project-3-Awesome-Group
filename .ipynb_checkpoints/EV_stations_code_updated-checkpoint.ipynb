# %%
import json
import pandas as pd
import requests
import numpy as np
import os

from pathlib import Path
from typing import Union
from collections import defaultdict
from sqlalchemy import create_engine
import sqlite3
import hvplot.pandas
import holoviews as hv
import geoviews as gv
gv.extension('bokeh')
from scipy.stats import linregress
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, output_file, show 
from citipy import citipy
import geopandas as gpd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# see website for information:
# https://developer.nrel.gov/docs/transportation/alt-fuel-stations-v1/all/

api_key = 'AWMepE53xJxr8Qu8yP3w6J6PLAf3ye6sO7Fsdvlc'
base_url = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.json'

# List of state codes
state_codes = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
               'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK',
               'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# Variable to store the total number of electric vehicle stations in the US
total_stations_us = 0

# Dictionary to store the totals for each state
state_totals = {}

for state_code in state_codes:
    query_params = {
        'fuel_type_code': 'ELEC',
        'state': state_code,
        'country': 'US',
        'api_key': api_key
    }

    # Make the API request
    response = requests.get(base_url, params=query_params)

    # Parse the JSON response
    data = response.json()

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the total number of electric vehicle stations for the specified state
        total_stations = data.get('total_results', 0)

        # Increment the total stations in the US variable
        total_stations_us += total_stations

        # Store the result in the dictionary
        state_totals[state_code] = total_stations

    else:
        # Print an error message if the request was not successful
        print(f'Error: {response.status_code} - {response.text}')

# Sort the dictionary by state in decreasing order based on total stations
sorted_totals = dict(sorted(state_totals.items(), key=lambda item: item[1], reverse=True))

# Create a folder named 'data_query' if it doesn't exist
output_folder = 'data_query'
os.makedirs(output_folder, exist_ok=True)

# Save the sorted totals to a JSON file in the 'data_query' folder
state_data_file_path = os.path.join(output_folder, 'electric_stations_by_state.json')
with open(state_data_file_path, 'w', encoding='utf-8') as state_data_file:
    json.dump(sorted_totals, state_data_file, ensure_ascii=False, indent=4)

# Print the total number of electric vehicle stations in the US
print(f'Total electric vehicle stations in the US for fuel type ELEC: {total_stations_us}')

print(f'The sorted totals have been saved to: {state_data_file_path}')
# Out:
# Total electric vehicle stations in the US for fuel type ELEC: 79633
# The sorted totals have been saved to: data_query\electric_stations_by_state.json

# %%
api_key = 'AWMepE53xJxr8Qu8yP3w6J6PLAf3ye6sO7Fsdvlc'
base_url = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.json'

# List of all US state codes
state_codes = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
    'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK',
    'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
]

# List of attributes to retrieve, including the new ones
attributes_to_retrieve = [
    'id', 'station_name', 'street_address', 'city', 'state', 'zip',
    'latitude', 'longitude', 'owner_type_code', 'ev_connector_types', 'ev_pricing',
    'geocode_status', 'access_code', 'ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_num', 'ev_other_evse'
]

# List to store detailed information for stations meeting the criteria
filtered_stations = []

for state_code in state_codes:
    query_params = {
        'fuel_type_code': 'ELEC',
        'state': state_code,
        'country': 'US',
        'restricted_access': 'false',  # Add restricted_access parameter
        'api_key': api_key
    }

    # Make the API request
    response = requests.get(base_url, params=query_params)

    # Parse the JSON response
    data = response.json()

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Add detailed information for each station meeting the criteria
        filtered_stations.extend([
            {attr: station[attr] for attr in attributes_to_retrieve}
            for station in data.get('fuel_stations', [])
        ])

    else:
        # Print an error message if the request was not successful
        print(f'Error: {response.status_code} - {response.text}')

# Print the total count of electric vehicle stations in the US after filtering
total_us_stations = sum(len(data.get('fuel_stations', [])) for state_code in state_codes)
print(f'Total electric vehicle stations in the US after filtering: {total_us_stations}')

# Create a folder named 'data_query' if it doesn't exist
output_folder = 'data_query'
os.makedirs(output_folder, exist_ok=True)

# Save the filtered stations to a JSON file in the 'data_query' folder
output_file_path = os.path.join(output_folder, 'filtered_stations_attributes.json')
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    json.dump(filtered_stations, output_file, ensure_ascii=False, indent=4)
    
    
print(f'The filtered stations with specified attributes have been saved to: {output_file_path}')
# Out:
# Total electric vehicle stations in the US after filtering: 7100
# The filtered stations with specified attributes have been saved to: data_query\filtered_stations_attributes.json

# %%
# Read in JSON previously created from API request
output_file_path = Path("data_query/filtered_stations_attributes.json")

# Load data from the JSON file
if output_file_path.exists():
    with output_file_path.open("r", encoding="utf8") as f:
        station_data = json.load(f)

# Create a DataFrame from the loaded data
station_df = pd.DataFrame(station_data)

# Organize the columns in the specified sequence
station_df = station_df[['id', 'station_name', 'street_address', 'city', 'state', 'zip',
         'latitude', 'longitude', 'owner_type_code', 'ev_connector_types', 'ev_pricing',
         'geocode_status', 'access_code', 'ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_num', 'ev_other_evse']]

# Display the DataFrame
# print(station_df.columns)

station_df.head()
# Out:
#       id                          station_name        street_address  \
# 0     17  Spire - Montgomery Operations Center      2951 Chestnut St
# 1    597                                 Spire       2828 Dauphin St
# 2  13712                       Gala Gas Co Inc  54 Old US Highway 82
# 3  13723                          Superior Gas          421 Noble St
# 4  13725                          Superior Gas       702 Memorial Dr
#
#          city state    zip   latitude  longitude owner_type_code  \
# 0  Montgomery    AL  36107  32.367916 -86.267021               T
# 1      Mobile    AL  36606  30.689832 -88.108861               T
# 2     Eufaula    AL  36027  31.912022 -85.150318               P
# 3    Anniston    AL  36201  33.642079 -85.828466               P
# 4    Piedmont    AL  36272  33.921589 -85.620314               P
#
#   ev_connector_types ev_pricing geocode_status access_code  \
# 0               None       None          200-9     private
# 1               None       None          200-9     private
# 2               None       None            GPS     private
# 3               None       None            GPS      public
# 4               None       None          200-9      public
#
#    ev_level1_evse_num  ev_level2_evse_num  ev_dc_fast_num ev_other_evse
# 0                 NaN                 NaN             NaN          None
# 1                 NaN                 NaN             NaN          None
# 2                 NaN                 NaN             NaN          None
# 3                 NaN                 NaN             NaN          None
# 4                 NaN                 NaN             NaN          None

# %%
api_key = 'AWMepE53xJxr8Qu8yP3w6J6PLAf3ye6sO7Fsdvlc'
base_url = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.json'

# Set the state parameter to 'CA' for California
state_code = 'CA'

# List of attributes to retrieve for map plotting
attributes_to_retrieve = [
    'id', 'station_name', 'street_address', 'city', 'state', 'zip',
    'latitude', 'longitude', 'owner_type_code', 'ev_connector_types', 'ev_pricing',
    'geocode_status', 'access_code'
]

# List to store detailed information for stations meeting the criteria
filtered_stations = []

query_params = {
    'fuel_type_code': 'ELEC',
    'state': state_code,
    'country': 'US',
    'restricted_access': 'false',  # Add restricted_access parameter
    'api_key': api_key
}

# Make the API request
response = requests.get(base_url, params=query_params)

# Parse the JSON response
data = response.json()

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Add detailed information for each station meeting the criteria
    for station in data.get('fuel_stations', []):
        # Check if all essential attributes have usable values
        if all(
            station.get(attr) is not None and station.get(attr) != ''
            for attr in attributes_to_retrieve
        ):
            # Combine 'ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_num', 'ev_other_evse'
            evse_combined = {
                'evse_combined': {
                    'ev_level1': station.get('ev_level1_evse_num', 0),
                    'ev_level2': station.get('ev_level2_evse_num', 0),
                    'ev_dc_fast': station.get('ev_dc_fast_num', 0),
                    'ev_other': station.get('ev_other_evse', 0)
                }
            }
            station.update(evse_combined)

            # Remove the individual evse attributes from the station
            for evse_attr in ['ev_level1_evse_num', 'ev_level2_evse_num', 'ev_dc_fast_num', 'ev_other_evse']:
                del station[evse_attr]

            filtered_stations.append({attr: station[attr] for attr in attributes_to_retrieve})

else:
    # Print an error message if the request was not successful
    print(f'Error: {response.status_code} - {response.text}')

# Create a DataFrame from the loaded data
df = pd.DataFrame(filtered_stations)

# Display the DataFrame
print(df)

# Print the total count of electric vehicle stations in California after filtering
total_ca_stations = len(df)
print(f'Total electric vehicle stations in California after filtering: {total_ca_stations}')

# Create a folder named 'data_query' if it doesn't exist
output_folder = 'data_query'
os.makedirs(output_folder, exist_ok=True)

# Save the filtered stations to a JSON file in the 'data_query' folder
output_file_path = os.path.join(output_folder, 'filtered_stations_combined_evse_CA.json')
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    json.dump(filtered_stations, output_file, ensure_ascii=False, indent=4)

print(f'The filtered stations with combined EVSE attributes in California have been saved to: {output_file_path}')
# Out:
#           id                                   station_name  \
# 0       1523                  Los Angeles Convention Center
# 1       1556                            LADWP - Sylmar West
# 2       1573                         LADWP - Fairfax Center
# 3       1583                 California Air Resources Board
# 4       6355                         Scripps Green Hospital
# ...      ...                                            ...
# 1763  323695  El Dorado County Department of Transportation
# 1764  323696                             Georgetown Library
# 1765  323697                 El Dorado County Senior Center
# 1766  323703                                 7Charge - Napa
# 1767  323706                         7Charge - Walnut Creek
#
#                street_address          city state    zip   latitude  \
# 0          1201 S Figueroa St   Los Angeles    CA  90015  34.040539
# 1        13201 Sepulveda Blvd        Sylmar    CA  91342  34.303090
# 2          2311 S Fairfax Ave   Los Angeles    CA  90016  34.036777
# 3            9530 Telstar Ave      El Monte    CA  91731  34.068720
# 4     10666 N Torrey Pines Rd      La Jolla    CA  92037  32.899470
# ...                       ...           ...   ...    ...        ...
# 1763       2441 Headington Rd   Placerville    CA  95667  38.715353
# 1764          6680 Orleans St    Georgetown    CA  95634  38.906376
# 1765            937 Spring St   Placerville    CA  95667  38.734068
# 1766            490 Devlin Rd          Napa    CA  94558  38.222550
# 1767    690 Ygnacio Valley Rd  Walnut Creek    CA  94596  37.906940
#
#        longitude owner_type_code     ev_connector_types  \
# 0    -118.271387               P                [J1772]
# 1    -118.480505              LG                [J1772]
# 2    -118.368841              LG                [J1772]
# 3    -118.064000              SG                [J1772]
# 4    -117.243000               P                [J1772]
# ...          ...             ...                    ...
# 1763 -120.842135              LG                [J1772]
# 1764 -120.837532               P                [J1772]
# 1765 -120.803026              LG                [J1772]
# 1766 -122.261940               P  [CHADEMO, J1772COMBO]
# 1767 -122.059390               P  [CHADEMO, J1772COMBO]
#
#                                              ev_pricing geocode_status  \
# 0                                     Free; parking fee            GPS
# 1                                                  Free          200-8
# 2                                                  Free          200-8
# 3                                                  Free            GPS
# 4                                     Free; parking fee            GPS
# ...                                                 ...            ...
# 1763                                               Free            GPS
# 1764                                               Free            GPS
# 1765                                     24 hours daily            GPS
# 1766  $0.46 per kWh; $1 per minute idle fee after a ...          200-8
# 1767  $0.46 per kWh; Idle parking fee of $1 per minu...          200-8
#
#      access_code
# 0         public
# 1        private
# 2        private
# 3         public
# 4         public
# ...          ...
# 1763      public
# 1764      public
# 1765      public
# 1766      public
# 1767      public
#
# [1768 rows x 13 columns]
# Total electric vehicle stations in California after filtering: 1768
# The filtered stations with combined EVSE attributes in California have been saved to: data_query\filtered_stations_combined_evse_CA.json

# %%
df.dtypes
# Out:
# id                      int64
# station_name           object
# street_address         object
# city                   object
# state                  object
# zip                    object
# latitude              float64
# longitude             float64
# owner_type_code        object
# ev_connector_types     object
# ev_pricing             object
# geocode_status         object
# access_code            object
# dtype: object

# %%
df.head(30)
# Out:
#        id                                     station_name  \
# 0    1523                    Los Angeles Convention Center
# 1    1556                              LADWP - Sylmar West
# 2    1573                           LADWP - Fairfax Center
# 3    1583                   California Air Resources Board
# 4    6355                           Scripps Green Hospital
# 5    6425                                Galleria at Tyler
# 6    6505           City of Pasadena - Holly Street Garage
# 7    6506               City of Pasadena - De Lacey Garage
# 8    6507            City of Pasadena - Schoolhouse Garage
# 9    7172                         Hyatt Regency Long Beach
# 10   7184  Los Angeles International Airport (LAX) - Lot 6
# 11   7194      Ontario Airport Hotel and Conference Center
# 12   7195              Courtyard Marriott - Oxnard Ventura
# 13   7196                            Hilton - Palm Springs
# 14   7206                              Inland Empire Foods
# 15   7212   Sacramento International Airport - Daily A Lot
# 16   7229                   City of Santa Monica - Airport
# 17   7230                      City of Santa Monica - Pier
# 18   7242                            Universal City Hilton
# 19   7250                          Office Max - Home Depot
# 20   7286                                  Arden Fair Mall
# 21  21358                                     Palace Hotel
# 22  21395         California State University - Northridge
# 23  21396         California State University - Northridge
# 24  21397         California State University - Northridge
# 25  21402       Los Angeles Harbor Department Headquarters
# 26  21419                                     Getty Center
# 27  21450                          LA County DPR Arboretum
# 28  21498                     City of Glendora - City Hall
# 29  21525                            Helms Bakery Building
#
#                 street_address            city state    zip   latitude  \
# 0           1201 S Figueroa St     Los Angeles    CA  90015  34.040539
# 1         13201 Sepulveda Blvd          Sylmar    CA  91342  34.303090
# 2           2311 S Fairfax Ave     Los Angeles    CA  90016  34.036777
# 3             9530 Telstar Ave        El Monte    CA  91731  34.068720
# 4      10666 N Torrey Pines Rd        La Jolla    CA  92037  32.899470
# 5       1299 Galleria at Tyler       Riverside    CA  92503  33.909914
# 6               150 E Holly St        Pasadena    CA  91103  34.147620
# 7              45 De Lacey Ave        Pasadena    CA  91105  34.145138
# 8                33 E Green St        Pasadena    CA  91105  34.145119
# 9               200 S Pine Ave      Long Beach    CA  90802  33.763700
# 10                 1 World Way     Los Angeles    CA  90045  33.943250
# 11             700 N Haven Ave         Ontario    CA  91764  34.071220
# 12          600 E Esplanade Dr          Oxnard    CA  93030  34.228315
# 13   400 E Tahquitz Canyon Way    Palm Springs    CA  92262  33.824004
# 14              5425 Wilson St       Riverside    CA  92509  34.018900
# 15                Lindbergh Dr      Sacramento    CA  95837  38.690050
# 16    3223 Donald Douglas Loop    Santa Monica    CA  90405  34.017081
# 17       200 Santa Monica Pier    Santa Monica    CA  90405  34.010021
# 18  333 Universal Terrace Pkwy  Universal City    CA  91608  34.138717
# 19         7075 Firestone Blvd          Downey    CA  90241  33.947560
# 20              1689 Arden Way      Sacramento    CA  95815  38.599693
# 21         2 New Montgomery St   San Francisco    CA  94105  37.788810
# 22           18111 Nordhoff St      Northridge    CA  91330  34.248959
# 23           18111 Nordhoff St      Northridge    CA  91330  34.241687
# 24           18111 Nordhoff St      Northridge    CA  91330  34.236853
# 25       425 S Palos Verdes St       San Pedro    CA  90731  33.740758
# 26        1200 Getty Center Dr     Los Angeles    CA  90049  34.077588
# 27           301 N Baldwin Ave         Arcadia    CA  91007  34.145528
# 28      114 S Vista Bonita Ave        Glendora    CA  91741  34.135560
# 29            8800 Venice Blvd     Los Angeles    CA  90034  34.029971
#
#      longitude owner_type_code ev_connector_types  \
# 0  -118.271387               P            [J1772]
# 1  -118.480505              LG            [J1772]
# 2  -118.368841              LG            [J1772]
# 3  -118.064000              SG            [J1772]
# 4  -117.243000               P            [J1772]
# 5  -117.459053               P            [J1772]
# 6  -118.147111              LG            [J1772]
# 7  -118.152655              LG            [J1772]
# 8  -118.150133              LG            [J1772]
# 9  -118.192000               P            [J1772]
# 10 -118.403342              LG            [J1772]
# 11 -117.575000               P            [J1772]
# 12 -119.170865               P            [J1772]
# 13 -116.543589               P            [J1772]
# 14 -117.380000               P            [J1772]
# 15 -121.588890               P            [J1772]
# 16 -118.447040              LG            [J1772]
# 17 -118.495830              LG            [J1772]
# 18 -118.359040               P          [NEMA520]
# 19 -118.153806               T            [J1772]
# 20 -121.427045               P            [J1772]
# 21 -122.401000               P            [J1772]
# 22 -118.523887               P            [J1772]
# 23 -118.528543               P            [J1772]
# 24 -118.532588               P            [J1772]
# 25 -118.281920               P            [J1772]
# 26 -118.474585               P   [J1772, NEMA520]
# 27 -118.050548               P            [J1772]
# 28 -117.864000              LG            [J1772]
# 29 -118.385231               P            [J1772]
#
#                                            ev_pricing geocode_status  \
# 0                                   Free; parking fee            GPS
# 1                                                Free          200-8
# 2                                                Free          200-8
# 3                                                Free            GPS
# 4                                   Free; parking fee            GPS
# 5                                                Free            GPS
# 6                                                Free          200-8
# 7                                   Free; parking fee            GPS
# 8   $1 for the first two hours, $2 each additional...            GPS
# 9                                                Free            GPS
# 10                     $2 service fee + $0.45 per kWh            GPS
# 11                                               Free            GPS
# 12                                               Free            GPS
# 13                                               Free            GPS
# 14                                               Free            GPS
# 15                                    $12 parking fee            GPS
# 16                                               Free            GPS
# 17                                               Free          200-9
# 18                                               Free          200-8
# 19                                               Free          200-8
# 20                                               Free          200-8
# 21                                     $7 per session            GPS
# 22                                               Free            GPS
# 23                       Free; parking is $8 per day.            GPS
# 24                                               Free            GPS
# 25                                               Free          200-9
# 26                                  Free; parking fee          200-9
# 27  $0.45 per kWh from 4pm-9pm; $0.30 per kWh all ...            GPS
# 28                                               Free            GPS
# 29  $1.35 per hour for first two hours, $3 per hou...          200-9
#
#    access_code
# 0       public
# 1      private
# 2      private
# 3       public
# 4       public
# 5       public
# 6       public
# 7       public
# 8       public
# 9       public
# 10      public
# 11      public
# 12      public
# 13      public
# 14      public
# 15      public
# 16      public
# 17      public
# 18      public
# 19      public
# 20      public
# 21      public
# 22      public
# 23      public
# 24      public
# 25      public
# 26      public
# 27      public
# 28      public
# 29      public

# %%
df.columns
# Out:
# Index(['id', 'station_name', 'street_address', 'city', 'state', 'zip',
#        'latitude', 'longitude', 'owner_type_code', 'ev_connector_types',
#        'ev_pricing', 'geocode_status', 'access_code'],
#       dtype='object')

# %%
df['owner_type_code']
# Out:
# 0        P
# 1       LG
# 2       LG
# 3       SG
# 4        P
#         ..
# 1763    LG
# 1764     P
# 1765    LG
# 1766     P
# 1767     P
# Name: owner_type_code, Length: 1768, dtype: object

# %%
#  create ColumnDataSource from data frame

source = ColumnDataSource(df)

# %%
hover = HoverTool(tooltips=[('zip', '@zip')])

map_plot_3 = df.hvplot.points(
    'longitude',
    'latitude',
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
    size=1.0,
    scale=1.0,
    color='city',
   
 
)

# # map_plot_3=df.hvplot.points(
# #    'longitude',
# #     'latitude',
# #     geo = True,
# #     tiles = 'OSM',
# #     frame_width = 800,
# #     frame_height = 600,
# #     size = 0.5,
# #     scale = 0.5,
# #     color = 'city',
# #     tools = [hover],
# # #     hover_cols='all'
# )

# Display the map
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (city)

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df
# Out:
#           id                                   station_name  \
# 0       1523                  Los Angeles Convention Center
# 1       1556                            LADWP - Sylmar West
# 2       1573                         LADWP - Fairfax Center
# 3       1583                 California Air Resources Board
# 4       6355                         Scripps Green Hospital
# ...      ...                                            ...
# 1763  323695  El Dorado County Department of Transportation
# 1764  323696                             Georgetown Library
# 1765  323697                 El Dorado County Senior Center
# 1766  323703                                 7Charge - Napa
# 1767  323706                         7Charge - Walnut Creek
#
#                street_address          city state    zip   latitude  \
# 0          1201 S Figueroa St   Los Angeles    CA  90015  34.040539
# 1        13201 Sepulveda Blvd        Sylmar    CA  91342  34.303090
# 2          2311 S Fairfax Ave   Los Angeles    CA  90016  34.036777
# 3            9530 Telstar Ave      El Monte    CA  91731  34.068720
# 4     10666 N Torrey Pines Rd      La Jolla    CA  92037  32.899470
# ...                       ...           ...   ...    ...        ...
# 1763       2441 Headington Rd   Placerville    CA  95667  38.715353
# 1764          6680 Orleans St    Georgetown    CA  95634  38.906376
# 1765            937 Spring St   Placerville    CA  95667  38.734068
# 1766            490 Devlin Rd          Napa    CA  94558  38.222550
# 1767    690 Ygnacio Valley Rd  Walnut Creek    CA  94596  37.906940
#
#        longitude owner_type_code     ev_connector_types  \
# 0    -118.271387               P                [J1772]
# 1    -118.480505              LG                [J1772]
# 2    -118.368841              LG                [J1772]
# 3    -118.064000              SG                [J1772]
# 4    -117.243000               P                [J1772]
# ...          ...             ...                    ...
# 1763 -120.842135              LG                [J1772]
# 1764 -120.837532               P                [J1772]
# 1765 -120.803026              LG                [J1772]
# 1766 -122.261940               P  [CHADEMO, J1772COMBO]
# 1767 -122.059390               P  [CHADEMO, J1772COMBO]
#
#                                              ev_pricing geocode_status  \
# 0                                     Free; parking fee            GPS
# 1                                                  Free          200-8
# 2                                                  Free          200-8
# 3                                                  Free            GPS
# 4                                     Free; parking fee            GPS
# ...                                                 ...            ...
# 1763                                               Free            GPS
# 1764                                               Free            GPS
# 1765                                     24 hours daily            GPS
# 1766  $0.46 per kWh; $1 per minute idle fee after a ...          200-8
# 1767  $0.46 per kWh; Idle parking fee of $1 per minu...          200-8
#
#      access_code
# 0         public
# 1        private
# 2        private
# 3         public
# 4         public
# ...          ...
# 1763      public
# 1764      public
# 1765      public
# 1766      public
# 1767      public
#
# [1768 rows x 13 columns]

# %%
df2 = df[['id', 'station_name', 'street_address', 'city', 'state', 'zip',
         'latitude', 'longitude', 'owner_type_code']]
df2
# Out:
#           id                                   station_name  \
# 0       1523                  Los Angeles Convention Center
# 1       1556                            LADWP - Sylmar West
# 2       1573                         LADWP - Fairfax Center
# 3       1583                 California Air Resources Board
# 4       6355                         Scripps Green Hospital
# ...      ...                                            ...
# 1763  323695  El Dorado County Department of Transportation
# 1764  323696                             Georgetown Library
# 1765  323697                 El Dorado County Senior Center
# 1766  323703                                 7Charge - Napa
# 1767  323706                         7Charge - Walnut Creek
#
#                street_address          city state    zip   latitude  \
# 0          1201 S Figueroa St   Los Angeles    CA  90015  34.040539
# 1        13201 Sepulveda Blvd        Sylmar    CA  91342  34.303090
# 2          2311 S Fairfax Ave   Los Angeles    CA  90016  34.036777
# 3            9530 Telstar Ave      El Monte    CA  91731  34.068720
# 4     10666 N Torrey Pines Rd      La Jolla    CA  92037  32.899470
# ...                       ...           ...   ...    ...        ...
# 1763       2441 Headington Rd   Placerville    CA  95667  38.715353
# 1764          6680 Orleans St    Georgetown    CA  95634  38.906376
# 1765            937 Spring St   Placerville    CA  95667  38.734068
# 1766            490 Devlin Rd          Napa    CA  94558  38.222550
# 1767    690 Ygnacio Valley Rd  Walnut Creek    CA  94596  37.906940
#
#        longitude owner_type_code
# 0    -118.271387               P
# 1    -118.480505              LG
# 2    -118.368841              LG
# 3    -118.064000              SG
# 4    -117.243000               P
# ...          ...             ...
# 1763 -120.842135              LG
# 1764 -120.837532               P
# 1765 -120.803026              LG
# 1766 -122.261940               P
# 1767 -122.059390               P
#
# [1768 rows x 9 columns]

# %%
df2.dtypes
# Out:
# id                   int64
# station_name        object
# street_address      object
# city                object
# state               object
# zip                 object
# latitude           float64
# longitude          float64
# owner_type_code     object
# dtype: object

# %%
df2['station_name'] = df2['station_name'].astype("string")
df2['street_address'] = df2['street_address'].astype("string")
df2['city'] = df2['city'].astype("string")
df2['state'] = df2['state'].astype("string")
df2['zip'] = df2['zip'].astype(np.int64)
df2['owner_type_code'] = df2['owner_type_code'].astype("string")
df2.dtypes
# Out:
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['station_name'] = df2['station_name'].astype("string")
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['street_address'] = df2['street_address'].astype("string")
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['city'] = df2['city'].astype("string")
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['state'] = df2['state'].astype("string")
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['zip'] = df2['zip'].astype(np.int64)
# C:\Users\Felix Egwuagu\AppData\Local\Temp\ipykernel_15720\1896166008.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['owner_type_code'] = df2['owner_type_code'].astype("string")
# id                          int64
# station_name       string[python]
# street_address     string[python]
# city               string[python]
# state              string[python]
# zip                         int64
# latitude                  float64
# longitude                 float64
# owner_type_code    string[python]
# dtype: object

# %%
df2
# Out:
#           id                                   station_name  \
# 0       1523                  Los Angeles Convention Center
# 1       1556                            LADWP - Sylmar West
# 2       1573                         LADWP - Fairfax Center
# 3       1583                 California Air Resources Board
# 4       6355                         Scripps Green Hospital
# ...      ...                                            ...
# 1763  323695  El Dorado County Department of Transportation
# 1764  323696                             Georgetown Library
# 1765  323697                 El Dorado County Senior Center
# 1766  323703                                 7Charge - Napa
# 1767  323706                         7Charge - Walnut Creek
#
#                street_address          city state    zip   latitude  \
# 0          1201 S Figueroa St   Los Angeles    CA  90015  34.040539
# 1        13201 Sepulveda Blvd        Sylmar    CA  91342  34.303090
# 2          2311 S Fairfax Ave   Los Angeles    CA  90016  34.036777
# 3            9530 Telstar Ave      El Monte    CA  91731  34.068720
# 4     10666 N Torrey Pines Rd      La Jolla    CA  92037  32.899470
# ...                       ...           ...   ...    ...        ...
# 1763       2441 Headington Rd   Placerville    CA  95667  38.715353
# 1764          6680 Orleans St    Georgetown    CA  95634  38.906376
# 1765            937 Spring St   Placerville    CA  95667  38.734068
# 1766            490 Devlin Rd          Napa    CA  94558  38.222550
# 1767    690 Ygnacio Valley Rd  Walnut Creek    CA  94596  37.906940
#
#        longitude owner_type_code
# 0    -118.271387               P
# 1    -118.480505              LG
# 2    -118.368841              LG
# 3    -118.064000              SG
# 4    -117.243000               P
# ...          ...             ...
# 1763 -120.842135              LG
# 1764 -120.837532               P
# 1765 -120.803026              LG
# 1766 -122.261940               P
# 1767 -122.059390               P
#
# [1768 rows x 9 columns]

# %%
# hover = HoverTool(tooltips=[('owner_type_code', '@owner_type_code')])

map_plot_4 = df2.hvplot.points(
    'longitude',
    'latitude',
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
    size=0.5,
    scale=0.5,
    color='city',
    hover_cols='all'
)
    
    # Display the map
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (city,index,id,station_name,street_address,state,zip,owner_type_code)

# %%
#  export to csvd

df2.to_csv("data_query/California.csv", index_label="Index")

# %%
conn = sqlite3.connect('california2.db')

# %%
# create_sql = "CREATE TABLE IF NOT EXISTS California (id INTEGER, station_name TEXT, street_address TEXT, city TEXT, state TEXT, zip INTEGER, latitude INTEGER, longitude INTEGER, owner_type_code TEXT)"

# cursor = conn.cursor()

# cursor.execute(create_sql)

# %%
# for row in df2.itertuples():
#     insert_sql = f"INSERT INTO California (id, station_name, street_address, city, state, zip, latitude, longitude, owner_type_code) VALUES ({row[1]}, '{row[2]}', '{row[3]}', '{row[4]}', '{row[5]}', {row[6]}, {row[7]}, {row[8]}, '{row[9]}')"
#     cursor.execute(insert_sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[27], line 3
#       1 for row in df2.itertuples():
#       2     insert_sql = f"INSERT INTO California (id, station_name, street_address, city, state, zip, latitude, longitude, owner_type_code) VALUES ({row[1]}, '{row[2]}', '{row[3]}', '{row[4]}', '{row[5]}', {row[6]}, {row[7]}, {row[8]}, '{row[9]}')"
# ----> 3     cursor.execute(insert_sql)
#
# OperationalError: near "s": syntax error

# %%
# for row in df2.itertuples():
#     insert_sql = f"INSERT INTO California (id, station_name, street_address, city, state, zip, latitude, longitude, owner_type_code) VALUES ({row[1]}, '{row[2]}', '{row[3]}', '{row[4]}', '{row[5]}', {row[6]}, {row[7]}, {row[8]}, '{row[9]}')"
#     cursor.execute(insert_sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[28], line 3
#       1 for row in df2.itertuples():
#       2     insert_sql = f"INSERT INTO California (id, station_name, street_address, city, state, zip, latitude, longitude, owner_type_code) VALUES ({row[1]}, '{row[2]}', '{row[3]}', '{row[4]}', '{row[5]}', {row[6]}, {row[7]}, {row[8]}, '{row[9]}')"
# ----> 3     cursor.execute(insert_sql)
#
# OperationalError: near "s": syntax error

# %%
#  DataFrame all at once method 
df2.to_sql(name="California", con=conn, if_exists='replace', index=False)
# Out:
# 1768

# %%
conn.commit()
